# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaomaro/old_notebooks/blob/main/gapminder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
urlpd = 'https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv'

# %%
datasetpd = pd.read_csv(urlpd)

# %%
datasetpd.shape
# Out:
# (1704, 6)

# %%
datasetpd.size
# Out:
# 10224

# %%
sb.relplot(x="country", y = "gdpPercap", data = datasetpd)

# %%
datasetpd.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
#datasetpd_cols = datasetpd[['year','continent','lifeExp']]

# %%
#phase1 = datasetpd_cols.groupby(['year','continent'])

# %%
#phase1.size

# %%
#print(phase1.count)
# Out:
# <bound method DataFrameGroupBy.count of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f53a6c520f0>>

# %%
pd.pivot_table(datasetpd, index= 'continent', columns='year', values="lifeExp")
# Out:
# year            1952       1957       1962  ...       1997       2002       2007
# continent                                   ...
# Africa     39.135500  41.266346  43.319442  ...  53.598269  53.325231  54.806038
# Americas   53.279840  55.960280  58.398760  ...  71.150480  72.422040  73.608120
# Asia       46.314394  49.318544  51.563223  ...  68.020515  69.233879  70.728485
# Europe     64.408500  66.703067  68.539233  ...  75.505167  76.700600  77.648600
# Oceania    69.255000  70.295000  71.085000  ...  78.190000  79.740000  80.719500
#
# [5 rows x 12 columns]

# %%
sb.set()
pd.pivot_table(datasetpd, index= 'continent', columns='year', values="lifeExp").plot(kind= 'bar')
plt.ylabel("Live Expectancy")
# Out:
# Text(0, 0.5, 'Live Expectancy')

# %%
datasetpd.describe
# Out:
# <bound method NDFrame.describe of           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]>

# %%
datasetpd.isnull().any()
# Out:
# country      False
# year         False
# pop          False
# continent    False
# lifeExp      False
# gdpPercap    False
# dtype: bool

# %%
dataheat = pd.pivot_table(datasetpd, index= 'continent', columns='year', values="lifeExp")
sb.heatmap(dataheat, cmap="YlGnBu")
